# %%
import pandas as pd
import numpy as np
import math as ms
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.decomposition import KernelPCA
from sklearn.impute import SimpleImputer,KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import RFE
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif,chi2,f_oneway,f_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier,BaggingRegressor,BaggingClassifier,VotingRegressor,VotingClassifier,ExtraTreesRegressor
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB,ComplementNB,MultinomialNB,BernoulliNB

# %%
df=pd.read_csv('/home/astro/Downloads/WhatSie/egypt_House_prices.csv')

# %%
df.head()
# Out:
#         Type    Price Bedrooms Bathrooms Area Furnished   Level Compound  \
# 0     Duplex  4000000        3         3  400        No       7  Unknown
# 1  Apartment  4000000        3         3  160        No     10+  Unknown
# 2  Apartment  2250000        3         2  165        No       1  Unknown
# 3  Apartment  1900000        3         2  230        No      10  Unknown
# 4  Apartment  5800000        2         3  160        No  Ground  Eastown
#
#   Payment_Option  Delivery_Date  Delivery_Term                    City
# 0           Cash  Ready to move       Finished               Nasr City
# 1           Cash  Ready to move       Finished             Camp Caesar
# 2           Cash  Ready to move       Finished                   Smoha
# 3           Cash  Ready to move       Finished               Nasr City
# 4           Cash  Ready to move  Semi Finished  New Cairo - El Tagamoa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27361 entries, 0 to 27360
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Type            27361 non-null  object
#  1   Price           27359 non-null  object
#  2   Bedrooms        27158 non-null  object
#  3   Bathrooms       27190 non-null  object
#  4   Area            26890 non-null  object
#  5   Furnished       27361 non-null  object
#  6   Level           27361 non-null  object
#  7   Compound        27361 non-null  object
#  8   Payment_Option  27361 non-null  object
#  9   Delivery_Date   27361 non-null  object
#  10  Delivery_Term   27361 non-null  object
#  11  City            27361 non-null  object
# dtypes: object(12)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#              Type    Price Bedrooms Bathrooms   Area Furnished    Level  \
# count       27361    27359    27158     27190  26890     27361    27361
# unique         11     4182       12        12    786         3       14
# top     Apartment  3000000        3         2    120        No  Unknown
# freq         8506      311    11803      9186    663     16500    10439
#
#        Compound       Payment_Option  Delivery_Date Delivery_Term  \
# count     27361                27361          27361         27361
# unique      560                    4             10             5
# top     Unknown  Cash or Installment  Ready to move      Finished
# freq      11068                10842          12142         14375
#
#                           City
# count                    27361
# unique                     183
# top     New Cairo - El Tagamoa
# freq                      6789

# %%
df.isna().sum()
# Out:
# Type                0
# Price               2
# Bedrooms          203
# Bathrooms         171
# Area              471
# Furnished           0
# Level               0
# Compound            0
# Payment_Option      0
# Delivery_Date       0
# Delivery_Term       0
# City                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Type              0
# Price             0
# Bedrooms          0
# Bathrooms         0
# Area              0
# Furnished         0
# Level             0
# Compound          0
# Payment_Option    0
# Delivery_Date     0
# Delivery_Term     0
# City              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26730 entries, 0 to 27359
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Type            26730 non-null  object
#  1   Price           26730 non-null  object
#  2   Bedrooms        26730 non-null  object
#  3   Bathrooms       26730 non-null  object
#  4   Area            26730 non-null  object
#  5   Furnished       26730 non-null  object
#  6   Level           26730 non-null  object
#  7   Compound        26730 non-null  object
#  8   Payment_Option  26730 non-null  object
#  9   Delivery_Date   26730 non-null  object
#  10  Delivery_Term   26730 non-null  object
#  11  City            26730 non-null  object
# dtypes: object(12)
# memory usage: 2.7+ MB

# %%
df.Price
# Out:
# 0         4000000
# 1         4000000
# 2         2250000
# 3         1900000
# 4         5800000
#            ...
# 27355     4800000
# 27356      890000
# 27357     4000000
# 27358    13800000
# 27359    35000000
# Name: Price, Length: 26730, dtype: object

# %%
df=df.replace('Unknown',np.nan)

# %%
df.isna().sum().sort_values()
# Out:
# Delivery_Term         0
# City                  0
# Payment_Option        0
# Type                 36
# Bathrooms            36
# Bedrooms             36
# Area                 36
# Price                37
# Furnished          8378
# Level              9833
# Delivery_Date      9914
# Compound          10734
# dtype: int64

# %%
df.drop(['Compound','Delivery_Date','Level','Furnished'],axis=1,inplace=True)

# %%
df.isna().sum().sort_values()
# Out:
# Delivery_Term      0
# City               0
# Payment_Option     0
# Type              36
# Bedrooms          36
# Bathrooms         36
# Area              36
# Price             37
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum().sort_values()
# Out:
# Type              0
# Price             0
# Bedrooms          0
# Bathrooms         0
# Area              0
# Payment_Option    0
# Delivery_Term     0
# City              0
# dtype: int64

# %%
df.head()
# Out:
#         Type    Price Bedrooms Bathrooms Area Payment_Option  Delivery_Term  \
# 0     Duplex  4000000        3         3  400           Cash       Finished
# 1  Apartment  4000000        3         3  160           Cash       Finished
# 2  Apartment  2250000        3         2  165           Cash       Finished
# 3  Apartment  1900000        3         2  230           Cash       Finished
# 4  Apartment  5800000        2         3  160           Cash  Semi Finished
#
#                      City
# 0               Nasr City
# 1             Camp Caesar
# 2                   Smoha
# 3               Nasr City
# 4  New Cairo - El Tagamoa

# %%
df=df.replace("10+",10)

# %%
df[["Price","Bedrooms","Bathrooms","Area"]]=df[["Price","Bedrooms","Bathrooms","Area"]].astype(float)

# %%
df[["Price","Bedrooms","Bathrooms","Area"]]=df[["Price","Bedrooms","Bathrooms","Area"]].astype(int)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.Payment_Option.unique()
# Out:
# array(['Cash', 'Cash or Installment', 'Unknown Payment', 'Installment'],
#       dtype=object)

# %%
df.Delivery_Term.unique()
# Out:
# array(['Finished', 'Semi Finished', 'Core & Shell', 'Unknown ',
#        'Not Finished'], dtype=object)

# %%
df=df.replace('Unknown ',np.nan)
df=df.replace('Unknown Payment',np.nan)

# %%
df.dropna(inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
df.City.unique()
# Out:
# array(['Nasr City', 'Camp Caesar', 'Smoha', 'New Cairo - El Tagamoa',
#        'Shorouk City', 'Sidi Beshr', 'Gesr Al Suez', 'Mokattam',
#        'New Capital City', 'New Damietta', 'Zahraa Al Maadi',
#        '6th of October', 'Mansura', 'New Heliopolis',
#        'Kafr al-Sheikh City', 'Badr City', 'Sheikh Zayed', 'Imbaba',
#        'Gamasa', 'Borg al-Arab', 'Mohandessin', 'Glim', 'Ain Sukhna',
#        'Abasiya', 'Maadi', 'Hadayek 6th of October', 'Madinaty', 'Haram',
#        'Damietta City', '10th of Ramadan', 'Heliopolis', 'Rehab City',
#        'Dar al-Salaam', 'North Coast', 'Nakheel', 'Hadayek al-Ahram',
#        'Bacchus', 'Hurghada', 'Agouza', 'Tura', 'Faisal District',
#        'Mandara', 'Helmeyat El Zaytoun', 'Katameya', 'Alamein',
#        'Qasr al-Nil', 'Miami', 'Hadayek al-Kobba', 'Tersa',
#        'Mostakbal City', 'Agami', 'Ras al-Bar', 'Port Fouad',
#        'Salam City', 'Aswan City', 'Helwan', 'Bolkly', '15 May City',
# ...

# %%
x=df.drop('City',axis=1)

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from xgboost import XGBRegressor # أو الموديل الذي استقررت عليه في النوت بوك
import joblib

# تحديد الأعمدة بناءً على الكود الخاص بك
categorical_features = ['Payment_Option', 'Delivery_Term', 'City']
numerical_features = ['Bedrooms', 'Bathrooms', 'Area']

# بناء معالج البيانات (Preprocessing)
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ])

# إنشاء الـ Pipeline الكامل
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', XGBRegressor()) # تم اختيار XGB بناءً على استيرادك له في الكود
])

# %%
# x=pd.get_dummies(x)

# %%
# x=x.astype(int)

# %%
# df=pd.concat([df['City'],x],axis=1)

# %%
df
# Out:
#                     Type     Price  Bedrooms  Bathrooms  Area  \
# 0                 Duplex   4000000         3          3   400
# 1              Apartment   4000000         3          3   160
# 2              Apartment   2250000         3          2   165
# 3              Apartment   1900000         3          2   230
# 4              Apartment   5800000         2          3   160
# ...                  ...       ...       ...        ...   ...
# 20394  Stand Alone Villa  16500000         4          4   620
# 20395  Stand Alone Villa  16000000         5          5   530
# 20396  Stand Alone Villa   4800000         4          3   165
# 20397         Town House   4000000         4          3   218
# 20398         Twin House  13800000         3          4   308
#
#             Payment_Option  Delivery_Term                    City
# 0                     Cash       Finished               Nasr City
# 1                     Cash       Finished             Camp Caesar
# ...

# %%
X=df.drop('Price',axis=1)
y=df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,shuffle=True,random_state=23)

# %%
model_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Bedrooms', 'Bathrooms',
#                                                    'Area']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Payment_Option',
#                                                    'Delivery_Term',
#                                                    'City'])])),
#                 ('regressor',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None,...
#                               feature_types=None, feature_weights=None,
#                               gamma=None, grow_policy=None,
# ...

# %%
from category_encoders import TargetEncoder

# %%
target=TargetEncoder(cols=['City'])

# %%
X_train = target.fit_transform(X_train, y_train)

X_test = target.transform(X_test)

# %%
# scaler = StandardScaler()

# X_train = scaler.fit_transform(X_train)

# X_test = scaler.transform(X_test)

# %%
from models import regression_models,run_regression_models

# %%
# result=run_regression_models(regression_models,X_train,X_test,y_train,y_test)

# %%
result
# Out:
#               model     train_mse      test_mse  train_r2   test_r2
# 6      RandomForest  2.640826e+12  1.040719e+13  0.917509  0.663873
# 7  GradientBoosting  1.041970e+13  1.103243e+13  0.674521  0.643680
# 4               KNN  9.707353e+12  1.167034e+13  0.696772  0.623077
# 1             Ridge  1.556989e+13  1.340987e+13  0.513645  0.566894
# 2             Lasso  1.556989e+13  1.340993e+13  0.513645  0.566892
# 0  LinearRegression  1.556989e+13  1.340993e+13  0.513645  0.566892
# 3        ElasticNet  1.560173e+13  1.341007e+13  0.512650  0.566888
# 8          AdaBoost  1.564292e+13  1.651669e+13  0.511364  0.466552
# 5      DecisionTree  9.544375e+11  1.675270e+13  0.970186  0.458929

# %%
from xgboost import XGBRegressor

# %%
xg=XGBRegressor()

# %%
# xg.fit(X_train,y_train)

# %%
# y_pred=xg.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
# r2_score(y_test,y_pred)

# %%
import pickle

# %%
import joblib

# %%
joblib.dump(xg,"model.joblib")
# Out:
# ['model.joblib']

# %%
joblib.dump(scaler,"scaler.joblib")
# Out:
# ['scaler.joblib']

# %%
joblib.dump(target,"target.joblib")
# Out:
# ['target.joblib']

# %%
joblib.dump(X.columns, "columns.joblib")
# Out:
# ['columns.joblib']

# %%
# from sklearn.preprocessing import LabelEncoder

# label_encoder = LabelEncoder()
# y_encoded = label_encoder.fit_transform(y)

# joblib.dump(label_encoder, "label_encoder.joblib")

# %%
joblib.dump(model_pipeline, 'house_price_pipeline.joblib')
# Out:
# ['house_price_pipeline.joblib']
