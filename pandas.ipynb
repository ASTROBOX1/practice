# %%
import pandas as pd
import numpy as np

# %%
ser1 =pd.Series([1,2,3,4])

# %%
data= np.random.randn(3,3)
data[1][2]=None

# %%
columns=['a','b','c']
index=['a','b','c']

# %%
# df=pd.DataFrame(data=data,index=index,columns=columns)
# df
# Out:
#           a         b         c
# a  0.793787 -0.870772 -0.814098
# b -0.318879 -1.550051       NaN
# c -0.037765 -0.201134 -0.613902

# %%
# Out:
#           a         b         c
# a  0.793787 -0.870772 -0.814098
# b -0.318879 -1.550051       NaN

# %%
df=pd.read_csv('/home/astro/Downloads/WhatSie/data.csv',index='rank')
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df=pd.read_csv('/home/astro/Downloads/WhatSie/data.csv',index='rank')
#       2 df.head(10)
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
df=pd.read_csv('/home/astro/Downloads/WhatSie/data.csv',co=['b','c','d'])
df.to_csv('out.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df=pd.read_csv('/home/astro/Downloads/WhatSie/data.csv',co=['b','c','d'])
#       2 df.to_csv('out.csv')
#
# TypeError: read_csv() got an unexpected keyword argument 'co'

# %%
df.iloc[-1]
# Out:
# rank                      102
# Date                2/20/2025
# state                 Wyoming
# state_code                 WY
# 2020_census          576851.0
# percent_of_total       0.0017
# Name: 101, dtype: object

# %%
from matplotlib import axis


df.drop('percent_of_total',axis=1)
# Out:
#      rank       Date         state state_code  2020_census
# 0       1   1/1/2025    California         CA   39538223.0
# 1       2   1/2/2025         Texas         TX   29145505.0
# 2       3   1/3/2025       Florida         FL   21538187.0
# 3       4   1/4/2025           NaN         NY          NaN
# 4       5   1/5/2025  Pennsylvania         PA   13002700.0
# ..    ...        ...           ...        ...          ...
# 97     98  2/16/2025  North Dakota         ND     779094.0
# 98     99  2/17/2025        Alaska         AK     733391.0
# 99    100  2/18/2025            DC         DC     689545.0
# 100   101  2/19/2025       Vermont         VT     643077.0
# 101   102  2/20/2025       Wyoming         WY     576851.0
#
# [102 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# b    8
# c    8
# d    4
# dtype: int64

# %%
df[["state","percent_of_total"]].head()
# Out:
#           state  percent_of_total
# 0    California            0.1191
# 1         Texas            0.0874
# 2       Florida            0.0647
# 3           NaN            0.0586
# 4  Pennsylvania            0.0386

# %%
df[(df['state']=="California") & (df["2020_census"]>576851.0)]
df.reset_index('rank')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 2
#       1 df[(df['state']=="California") & (df["2020_census"]>576851.0)]
# ----> 2 df.reset_index('rank')
#
# File ~/.conda/envs/ds_env/lib/python3.11/site-packages/pandas/core/frame.py:6447, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6445 if not isinstance(level, (tuple, list)):
#    6446     level = [level]
# -> 6447 level = [self.index._get_level_number(lev) for lev in level]
#    6448 if len(level) < self.index.nlevels:
#    6449     new_index = self.index.droplevel(level)
#
# File ~/.conda/envs/ds_env/lib/python3.11/site-packages/pandas/core/frame.py:6447, in <listcomp>(.0)
#    6445 if not isinstance(level, (tuple, list)):
#    6446     level = [level]
# -> 6447 level = [self.index._get_level_number(lev) for lev in level]
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# state               14
# state_code           8
# 2020_census          8
# percent_of_total     4
# Date                 0
# rank                 0
# dtype: int64

# %%
df.loc[1]
# Out:
# rank                         2
# Date                  1/2/2025
# state                    Texas
# state_code                  TX
# 2020_census         29145505.0
# percent_of_total        0.0874
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# rank                         2
# Date                  1/2/2025
# state                    Texas
# state_code                  TX
# 2020_census         29145505.0
# percent_of_total        0.0874
# Name: 1, dtype: object

# %%
df.plot(kind='hist',x='state',y='percent_of_total')
# Out:
# <Axes: ylabel='Frequency'>
