# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_excel('Data/FLAIR.xlsx')

# %%
df.head()
# Out:
#   Grade    VoxelVolume  Maximum3DDiameter     MeshVolume  MajorAxisLength  \
# 0    G3   66128.198147          76.445742   65961.755872        65.085462
# 1    G3   42859.730845          80.357188   42698.161698        60.921389
# 2    G3   82152.352810          75.203906   82058.924059        59.102747
# 3    G2  170801.825047         104.667500  170412.851512        88.798239
# 4    G3  183574.563980         136.212971  183314.798733       108.628040
#
#    Sphericity  LeastAxisLength  Elongation  SurfaceVolumeRatio  \
# 0    0.429089        38.263796    0.767897            0.278937
# 1    0.242761        32.889643    0.828271            0.569949
# 2    0.631804        40.248334    0.866919            0.176141
# 3    0.522666        49.082383    0.669372            0.166888
# 4    0.406995        46.002675    0.578327            0.209168
#
#    Maximum2DDiameterSlice  ...  HighGrayLevelZoneEmphasis.8  \
# 0               75.668933  ...                   277.402591
# ...

# %%
X=df.drop('Grade',axis=1)
y=df['Grade']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.1,random_state=42)

# %%
from sklearn.decomposition import PCA

# %%
pc=PCA(n_components=14)

# %%
data=pc.fit_transform(X_train)

# %%
data.shape
# Out:
# (121, 14)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
de=DecisionTreeClassifier(criterion="gini",
        max_depth=None,
        min_samples_split=2,
        min_samples_leaf=1,
        random_state=42)

# %%
de.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred= de.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.7857142857142857

# %%
de.fit(data,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
pc2=PCA(n_components=14)

# %%
data2=pc.fit_transform(X_test)

# %%
y_pred= de.predict(data2)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.6428571428571429

# %%
from sklearn.feature_selection import SelectKBest ,chi2,f_classif

# %%
from sqlalchemy import func


f=SelectKBest(score_func=f_classif,k=45)

# %%
newData=f.fit_transform(X_train,y_train)

# %%
newData.shape
# Out:
# (121, 45)

# %%
f.get_feature_names_out()
# Out:
# array(['VoxelVolume', 'Maximum3DDiameter', 'MeshVolume', 'Sphericity',
#        'LeastAxisLength', 'SurfaceArea', 'MinorAxisLength',
#        'Maximum2DDiameterColumn', 'Maximum2DDiameterRow',
#        'GrayLevelVariance', 'SumSquares', 'ClusterTendency',
#        'InterquartileRange', 'Skewness', 'RobustMeanAbsoluteDeviation',
#        'TotalEnergy', 'Variance', 'GrayLevelVariance.1', 'Idn.1', 'MCC.1',
#        'TotalEnergy.1', 'Maximum.1', 'Kurtosis.1', 'TotalEnergy.2',
#        'Imc2.4', 'RunEntropy.4', 'Coarseness.4', 'DependenceEntropy.7',
#        'DependenceNonUniformityNormalized.7', 'DependenceVariance.7',
#        'Imc2.7', 'Energy.7', 'ZoneVariance.7', 'LargeAreaEmphasis.7',
#        'ZoneEntropy.7', 'GrayLevelVariance.24', 'SumSquares.8',
#        'ClusterTendency.8', 'InterquartileRange.8', 'Skewness.8',
#        'RobustMeanAbsoluteDeviation.8', 'TotalEnergy.8', 'Minimum.8',
#        'Variance.8', 'GrayLevelVariance.25'], dtype=object)

# %%
from sklearn.feature_selection import RFE 
model=DecisionTreeClassifier()
rf=RFE(estimator=model,n_features_to_select=6)
fit=rf.fit(X_train,y_train)

# %%
fit.ranking_
# Out:
# array([846, 845, 844, 843, 842, 841, 840, 839, 838, 837, 836, 835, 834,
#        833, 832, 831, 830, 829, 828, 827, 826, 825, 824, 822, 821, 820,
#        819, 818, 817, 816, 815, 814, 813, 812, 811, 810, 809, 808, 807,
#        806, 805, 804, 803, 802, 801, 800, 799, 798, 797, 796, 795, 794,
#        793, 792, 791, 790, 789, 788, 787, 786, 785, 784, 783, 782, 781,
#        780, 779, 777, 776, 775, 774, 773, 772, 771, 770, 769, 768, 767,
#        766, 765, 764, 763, 762, 761, 760, 759, 758, 757, 756, 755, 754,
#        753, 752, 751, 750, 749, 748, 747, 745, 744, 743, 742, 741, 740,
#        739, 738, 737, 736, 735, 734, 733, 732, 731, 730, 729, 728, 727,
#        726, 725, 724, 723, 722, 721, 720, 719, 718, 717, 716, 715, 714,
#        713, 712, 711, 710, 709, 708,   2,  21,  19,  18,  17,  15,  13,
#         11,  22,  26,   1,  30,  31,  20,  36,  32,  40,  44,  43,  27,
#         38,  51,  52,  55,  46,  49,  60,  64,  57,  65,  68,  59,  72,
# ...

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
importa=pd.Series(dt.feature_importances_,index=X_train.columns)

# %%
importa=importa.sort_values(ascending=False)

# %%
importa
# Out:
# GrayLevelNonUniformity.17    0.131220
# MaximumProbability.3         0.088900
# ClusterShade.5               0.087568
# Imc1.5                       0.084966
# SumEntropy.1                 0.083025
#                                ...
# Coarseness.2                 0.000000
# Complexity.2                 0.000000
# Strength.2                   0.000000
# Contrast.5                   0.000000
# Busyness.8                   0.000000
# Length: 851, dtype: float64

# %%
select_fetuer=importa.nlargest(5).tolist()

# %%
select_fetuer
# Out:
# [0.1312196087762861,
#  0.08889952707656726,
#  0.08756807221722761,
#  0.08496606426957445,
#  0.08302490548494473]

# %%
from sklearn.model_selection import GridSearchCV

# %%
model=DecisionTreeClassifier()

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [10, 20, 30],
    'max_depth': [None, 10, 20, 30]
}

grid = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy'
)

# %%
grid
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'n_estimators': [10, 20, 30]},
#              scoring='accuracy')

# %%
param_grid = {
    'max_depth': [None, 10, 20, 30]
}

grid = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy'
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 grid.fit(X_train,y_train)
#
# File ~/.conda/envs/ds_env/lib/python3.11/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~/.conda/envs/ds_env/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1053, in BaseSearchCV.fit(self, X, y, **params)
#    1047     results = self._format_results(
#    1048         all_candidate_params, n_splits, all_out, all_more_results
#    1049     )
#    1051     return results
# ...

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.discriminant_analysis import StandardScaler


pipe=Pipeline([
    ('scaler',StandardScaler()),
    ('DecisionTreeClassifier',DecisionTreeClassifier())
])
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('DecisionTreeClassifier', DecisionTreeClassifier())])

# %%
from models import classifications_models,run_classification_models

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_test_enc  = le.transform(y_test)
results = run_classification_models(classifications_models, X_train, X_test, y_train_enc, y_test_enc)
results
# Out:
# /home/astro/.conda/envs/ds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# /home/astro/.conda/envs/ds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
