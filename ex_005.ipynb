# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('Data/Jobs/Test.csv')

# %%
df.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  458989  Female          Yes   36       Yes    Engineer              0.0
# 1  458994    Male          Yes   37       Yes  Healthcare              8.0
# 2  458996  Female          Yes   69        No         NaN              0.0
# 3  459000    Male          Yes   59        No   Executive             11.0
# 4  459001  Female           No   19        No   Marketing              NaN
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          1.0  Cat_6            B
# 1        Average          4.0  Cat_6            A
# 2            Low          1.0  Cat_6            A
# 3           High          2.0  Cat_6            B
# 4            Low          4.0  Cat_6            A

# %%
df.describe()
# Out:
#                   ID          Age  Work_Experience  Family_Size
# count    2627.000000  2627.000000      2358.000000  2514.000000
# mean   463433.918919    43.649791         2.552587     2.825378
# std      2618.245698    16.967015         3.341094     1.551906
# min    458989.000000    18.000000         0.000000     1.000000
# 25%    461162.500000    30.000000         0.000000     2.000000
# 50%    463379.000000    41.000000         1.000000     2.000000
# 75%    465696.000000    53.000000         4.000000     4.000000
# max    467968.000000    89.000000        14.000000     9.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2627 entries, 0 to 2626
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               2627 non-null   int64
#  1   Gender           2627 non-null   object
#  2   Ever_Married     2577 non-null   object
#  3   Age              2627 non-null   int64
#  4   Graduated        2603 non-null   object
#  5   Profession       2589 non-null   object
#  6   Work_Experience  2358 non-null   float64
#  7   Spending_Score   2627 non-null   object
#  8   Family_Size      2514 non-null   float64
#  9   Var_1            2595 non-null   object
#  10  Segmentation     2627 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 225.9+ KB

# %%
df.isna().sum().sort_values()
# Out:
# ID                   0
# Gender               0
# Age                  0
# Spending_Score       0
# Segmentation         0
# Graduated           24
# Var_1               32
# Profession          38
# Ever_Married        50
# Family_Size        113
# Work_Experience    269
# dtype: int64

# %%
df.drop('ID',inplace=True,axis=1)

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isna().sum().sort_values()
# Out:
# Gender             0
# Ever_Married       0
# Age                0
# Graduated          0
# Profession         0
# Work_Experience    0
# Spending_Score     0
# Family_Size        0
# Var_1              0
# Segmentation       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2154 entries, 0 to 2626
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           2154 non-null   object
#  1   Ever_Married     2154 non-null   object
#  2   Age              2154 non-null   int64
#  3   Graduated        2154 non-null   object
#  4   Profession       2154 non-null   object
#  5   Work_Experience  2154 non-null   float64
#  6   Spending_Score   2154 non-null   object
#  7   Family_Size      2154 non-null   float64
#  8   Var_1            2154 non-null   object
#  9   Segmentation     2154 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 185.1+ KB

# %%
df.head()
# Out:
#    Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  Female          Yes   36       Yes    Engineer              0.0
# 1    Male          Yes   37       Yes  Healthcare              8.0
# 3    Male          Yes   59        No   Executive             11.0
# 5    Male          Yes   47       Yes      Doctor              0.0
# 6    Male          Yes   61       Yes      Doctor              5.0
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          1.0  Cat_6            B
# 1        Average          4.0  Cat_6            A
# 3           High          2.0  Cat_6            B
# 5           High          5.0  Cat_4            C
# 6            Low          3.0  Cat_6            D

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['Gender']=le.fit_transform(df['Gender'])

# %%
df['Ever_Married']=le.fit_transform(df['Ever_Married'])

# %%
df['Graduated']=le.fit_transform(df['Graduated'])

# %%
df.head()
# Out:
#    Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0       0             1   36          1    Engineer              0.0
# 1       1             1   37          1  Healthcare              8.0
# 3       1             1   59          0   Executive             11.0
# 5       1             1   47          1      Doctor              0.0
# 6       1             1   61          1      Doctor              5.0
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          1.0  Cat_6            B
# 1        Average          4.0  Cat_6            A
# 3           High          2.0  Cat_6            B
# 5           High          5.0  Cat_4            C
# 6            Low          3.0  Cat_6            D

# %%
df['Spending_Score']=df['Spending_Score'].map({'Low':0,'Average':1,'High':2})

# %%
df.head()
# Out:
#    Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0       0             1   36          1    Engineer              0.0
# 1       1             1   37          1  Healthcare              8.0
# 3       1             1   59          0   Executive             11.0
# 5       1             1   47          1      Doctor              0.0
# 6       1             1   61          1      Doctor              5.0
#
#    Spending_Score  Family_Size  Var_1 Segmentation
# 0               0          1.0  Cat_6            B
# 1               1          4.0  Cat_6            A
# 3               2          2.0  Cat_6            B
# 5               2          5.0  Cat_4            C
# 6               0          3.0  Cat_6            D

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2154 entries, 0 to 2626
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           2154 non-null   int64
#  1   Ever_Married     2154 non-null   int64
#  2   Age              2154 non-null   int64
#  3   Graduated        2154 non-null   int64
#  4   Profession       2154 non-null   object
#  5   Work_Experience  2154 non-null   float64
#  6   Spending_Score   2154 non-null   int64
#  7   Family_Size      2154 non-null   float64
#  8   Var_1            2154 non-null   object
#  9   Segmentation     2154 non-null   object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 185.1+ KB

# %%
df['Var_1'].unique()
# Out:
# array(['Cat_6', 'Cat_4', 'Cat_3', 'Cat_1', 'Cat_2', 'Cat_5', 'Cat_7'],
#       dtype=object)

# %%
df = pd.get_dummies(df, columns=['Profession'], drop_first=True)

# %%
df['Var_1']=df['Var_1'].map({'Cat_1':0,'Cat_2':1,'Cat_3':2,'Cat_4':3,'Cat_5':4,'Cat_6':5,'Cat_7':6})

# %%
df['Segmentation'].unique()
# Out:
# array(['B', 'A', 'C', 'D'], dtype=object)

# %%
df['Segmentation']=df['Segmentation'].map({'A':3,'B':2,'C':1,'D':0})

# %%
df.head()
# Out:
#    Gender  Ever_Married  Age  Graduated  Work_Experience  Spending_Score  \
# 0       0             1   36          1              0.0               0
# 1       1             1   37          1              8.0               1
# 3       1             1   59          0             11.0               2
# 5       1             1   47          1              0.0               2
# 6       1             1   61          1              5.0               0
#
#    Family_Size  Var_1  Segmentation  Profession_Doctor  Profession_Engineer  \
# 0          1.0      5             2              False                 True
# 1          4.0      5             3              False                False
# 3          2.0      5             2              False                False
# 5          5.0      3             1               True                False
# 6          3.0      5             0               True                False
#
# ...

# %%
df_train=pd.read_csv('/home/astro/Documents/Train.csv')

# %%
df_train.isnull().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married       140
# Age                  0
# Graduated           78
# Profession         124
# Work_Experience    829
# Spending_Score       0
# Family_Size        335
# Var_1               76
# Segmentation         0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8068 entries, 0 to 8067
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               8068 non-null   int64
#  1   Gender           8068 non-null   object
#  2   Ever_Married     7928 non-null   object
#  3   Age              8068 non-null   int64
#  4   Graduated        7990 non-null   object
#  5   Profession       7944 non-null   object
#  6   Work_Experience  7239 non-null   float64
#  7   Spending_Score   8068 non-null   object
#  8   Family_Size      7733 non-null   float64
#  9   Var_1            7992 non-null   object
#  10  Segmentation     8068 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 693.5+ KB

# %%
df_train.dropna(inplace=True)

# %%
df_train.reset_index(drop=True,inplace=True)

# %%
df_train.drop('ID',inplace=True,axis=1)

# %%
df_train.head()
# Out:
#    Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0    Male           No   22        No  Healthcare              1.0
# 1  Female          Yes   67       Yes    Engineer              1.0
# 2    Male          Yes   67       Yes      Lawyer              0.0
# 3    Male          Yes   56        No      Artist              0.0
# 4    Male           No   32       Yes  Healthcare              1.0
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          4.0  Cat_4            D
# 1            Low          1.0  Cat_6            B
# 2           High          2.0  Cat_6            B
# 3        Average          2.0  Cat_6            C
# 4            Low          3.0  Cat_6            C

# %%
df_train['Gender']=le.fit_transform(df_train['Gender'])

# %%
df_train['Ever_Married']=le.fit_transform(df_train['Ever_Married'])

# %%
df_train['Graduated']=le.fit_transform(df_train['Graduated'])

# %%
df_train = pd.get_dummies(df_train, columns=['Profession'], drop_first=True)

# %%
df_train['Var_1']=df_train['Var_1'].map({'Cat_1':0,'Cat_2':1,'Cat_3':2,'Cat_4':3,'Cat_5':4,'Cat_6':5,'Cat_7':6})

# %%
df_train['Spending_Score']=df_train['Spending_Score'].map({'Low':0,'Average':1,'High':2})

# %%
df_train['Segmentation']=df_train['Segmentation'].map({'A':3,'B':2,'C':1,'D':0})

# %%
df_train.head()
# Out:
#    Gender  Ever_Married  Age  Graduated  Work_Experience  Spending_Score  \
# 0       1             0   22          0              1.0               0
# 1       0             1   67          1              1.0               0
# 2       1             1   67          1              0.0               2
# 3       1             1   56          0              0.0               1
# 4       1             0   32          1              1.0               0
#
#    Family_Size  Var_1  Segmentation  Profession_Doctor  Profession_Engineer  \
# 0          4.0      3             0              False                False
# 1          1.0      5             2              False                 True
# 2          2.0      5             2              False                False
# 3          2.0      5             1              False                False
# 4          3.0      5             1              False                False
#
# ...

# %%
df=df.astype(int)
df_train=df_train.astype(int)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
df[['Age']]=sc.fit_transform(df[['Age']])

# %%
df_train[['Age']]=sc.fit_transform(df_train[['Age']])

# %%
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
sns.histplot(df_train['Age'], kde=True, color='blue')


plt.subplot(2, 2, 2)
sns.boxplot(x='Age', data=df_train)


plt.subplot(2, 2, 3)
sns.barplot(x='Age', y='Segmentation',data=df_train)


plt.subplot(2, 2, 4)
sns.lineplot(x='Work_Experience', y='Segmentation', data=df_train, hue='Graduated', alpha=0.6)


plt.tight_layout()
plt.show()

plt.figure(figsize=(12, 8))
corr = df_train.select_dtypes(include=['number']).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

plt.show()

plt.figure(figsize=(14, 6))
sns.barplot(x='Graduated', y='Segmentation', hue='Work_Experience', data=df_train)

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2154 entries, 0 to 2626
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Gender                    2154 non-null   int64
#  1   Ever_Married              2154 non-null   int64
#  2   Age                       2154 non-null   float64
#  3   Graduated                 2154 non-null   int64
#  4   Work_Experience           2154 non-null   int64
#  5   Spending_Score            2154 non-null   int64
#  6   Family_Size               2154 non-null   int64
#  7   Var_1                     2154 non-null   int64
#  8   Segmentation              2154 non-null   int64
#  9   Profession_Doctor         2154 non-null   int64
#  10  Profession_Engineer       2154 non-null   int64
#  11  Profession_Entertainment  2154 non-null   int64
#  12  Profession_Executive      2154 non-null   int64
#  13  Profession_Healthcare     2154 non-null   int64
# ...

# %%
X_train=df_train.drop('Segmentation',axis=1)
y_train=df_train['Segmentation']

# %%
X_test=df.drop('Segmentation',axis=1)
y_test=df['Segmentation']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split,cross_val_score,KFold

# %%
log=LogisticRegression(penalty='l2',max_iter=200)

# %%
log.fit(X_train,y_train)
# Out:
# /home/astro/.conda/envs/ds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# LogisticRegression(max_iter=200, penalty='l2')

# %%
y_pred=log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,classification_report,roc_curve,roc_auc_score,confusion_matrix

# %%
models = {"LogisticRegression":LogisticRegression(
    class_weight='balanced',
    penalty='l2',
    max_iter=200
    )}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

models['KNN']= KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=1)
models["RandomForest"] = RandomForestClassifier(class_weight='balanced', n_estimators=100)

# %%
accuracy=[]
for model_name , model in models.items():
    model.fit(X_train,y_train)
    y_pred_train=model.predict(X_train)
    y_pred_test=model.predict(X_test)

    accu_train=accuracy_score(y_train,y_pred_train)
    accu_test=accuracy_score(y_test,y_pred_test)

    recall_train=recall_score(y_train,y_pred_train,average='macro')
    recall_test=recall_score(y_test,y_pred_test,average='macro')
    
    precision_train=precision_score(y_train,y_pred_train,average='micro')
    precision_test=precision_score(y_test,y_pred_test,average='micro')

    f1_train=f1_score(y_train,y_pred_train,average='micro')
    f1_test=accuracy_score(y_test,y_pred_test)

    report_train=classification_report(y_train,y_pred_train)
    report_test=classification_report(y_test,y_pred_test)

    accuracy.append([accu_train,
            accu_test,
            recall_train,
            recall_test,
            precision_train,
            precision_test,
            f1_train,
            f1_test]
            )
# Out:
# /home/astro/.conda/envs/ds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(

# %%
accuracy=pd.DataFrame(accuracy,index=models,columns=['accu_train',
            'accu_test',
            'recall_train',
            'recall_test',
            'precision_train',
            'precision_test',
            'f1_train',
            'f1_test'])

# %%
accuracy
# Out:
#                     accu_train  accu_test  recall_train  recall_test  \
# LogisticRegression    0.513278   0.327762      0.506155     0.326412
# KNN                   0.632258   0.309192      0.626248     0.317650
# RandomForest          0.953788   0.317084      0.953244     0.316561
#
#                     precision_train  precision_test  f1_train   f1_test
# LogisticRegression         0.513278        0.327762  0.513278  0.327762
# KNN                        0.632258        0.309192  0.632258  0.309192
# RandomForest               0.953788        0.317084  0.953788  0.317084

# %%
from models import run_classification_models,classifications_models

# %%
selected_keys = ["GaussianNB","BernoulliNB"]
selected_models = {}

for key in selected_keys:
    selected_models[key] = classifications_models[key]

result = run_classification_models(selected_models, X_train, X_test, y_train, y_test)

# %%
result
# Out:
#          model  train_acc  test_acc  train_f1   test_f1
# 1  BernoulliNB   0.476969  0.319870  0.445884  0.301732
# 0   GaussianNB   0.479070  0.311513  0.445329  0.295524

# %%
result =run_classification_models(classifications_models, X_train, X_test, y_train, y_test)
# Out:
# /home/astro/.conda/envs/ds_env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Learning rate set to 0.087164
# 0:	learn: 1.3480547	total: 52.1ms	remaining: 52s
# 1:	learn: 1.3099355	total: 55.7ms	remaining: 27.8s
# 2:	learn: 1.2819874	total: 59.5ms	remaining: 19.8s
# 3:	learn: 1.2569506	total: 63.5ms	remaining: 15.8s
# 4:	learn: 1.2353040	total: 67.2ms	remaining: 13.4s
# 5:	learn: 1.2188851	total: 71.9ms	remaining: 11.9s
# 6:	learn: 1.2047386	total: 76.1ms	remaining: 10.8s
# 7:	learn: 1.1914974	total: 80.3ms	remaining: 9.96s
# 8:	learn: 1.1775464	total: 84.2ms	remaining: 9.27s
# 9:	learn: 1.1662506	total: 87.7ms	remaining: 8.68s
# ...

# %%
result.sort_values(by='test_acc',ascending=False)
# Out:
#                     model  train_acc  test_acc  train_f1   test_f1
# 7                AdaBoost   0.480570  0.333798  0.417798  0.298979
# 6        GradientBoosting   0.610503  0.328227  0.605388  0.327584
# 0      LogisticRegression   0.513278  0.327762  0.502480  0.327216
# 12     CatBoostClassifier   0.750338  0.322191  0.748130  0.322243
# 3            RandomForest   0.953788  0.320799  0.953775  0.322703
# 9             BernoulliNB   0.476969  0.319870  0.445884  0.301732
# 13         LGBMClassifier   0.699625  0.318942  0.695868  0.317350
# 2            DecisionTree   0.953788  0.315692  0.953685  0.317723
# 11          XGBClassifier   0.777194  0.314763  0.775272  0.313544
# 10  HistGradient Boosting   0.729032  0.314299  0.725995  0.313411
# 5              ExtraTrees   0.953788  0.311978  0.953685  0.313513
# 1                     KNN   0.629857  0.311978  0.622042  0.306231
# 8              GaussianNB   0.479070  0.311513  0.445329  0.295524
# ...
