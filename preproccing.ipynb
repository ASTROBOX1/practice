# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore
# skew دي عشان اعرف النورمال

# %%
df=pd.read_csv('/home/astro/Downloads/healthcare-dataset-stroke-data.csv')

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
data=pd.read_csv('/home/astro/Downloads/WhatSie/salaries.csv')

# %%
data.head()
# Out:
#    ID  work_year experience_level employment_type       job_title    salary  \
# 0   1     2025.0               EX              FT    Head of Data  348516.0
# 1   2     2025.0               EX              FT    Head of Data  232344.0
# 2   3     2025.0               SE              FT  Data Scientist  145400.0
# 3   4     2025.0               SE              FT  Data Scientist   81600.0
# 4   5        NaN               MI              FT        Engineer  160000.0
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         348516                 US           NaN
# 1             USD         232344                 US           0.0
# 2             USD         145400                 US           NaN
# 3             USD          81600                 US           0.0
# 4             USD         160000                 US           NaN
#
#   company_location company_size  years_of_experience
# 0              NaN            M                 14.0
# ...

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   4909.000000  4909.000000   4909.000000    4909.000000
# mean   37064.313506    42.865374      0.091872       0.049501
# std    20995.098457    22.555115      0.288875       0.216934
# min       77.000000     0.080000      0.000000       0.000000
# 25%    18605.000000    25.000000      0.000000       0.000000
# 50%    37608.000000    44.000000      0.000000       0.000000
# 75%    55220.000000    60.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        4909.000000  4909.000000  4909.000000
# mean          105.305150    28.893237     0.042575
# std            44.424341     7.854067     0.201917
# min            55.120000    10.300000     0.000000
# 25%            77.070000    23.500000     0.000000
# 50%            91.680000    28.100000     0.000000
# ...

# %%
data.drop(['ID'],axis=1,inplace=True)

# %%
data.reset_index(drop=True,inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(18909)

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isna().sum().sort_values(ascending=False)
# Out:
# company_location       54287
# remote_ratio           21684
# years_of_experience    16518
# company_size           14859
# work_year               8845
# job_title               7048
# salary                  1442
# experience_level           0
# employment_type            0
# employee_residence         0
# salary_currency            0
# salary_in_usd              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 132536 entries, 0 to 151444
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   work_year            123691 non-null  float64
#  1   experience_level     132536 non-null  object
#  2   employment_type      132536 non-null  object
#  3   job_title            125488 non-null  object
#  4   salary               131094 non-null  float64
#  5   salary_currency      132536 non-null  object
#  6   salary_in_usd        132536 non-null  int64
#  7   employee_residence   132536 non-null  object
#  8   remote_ratio         110852 non-null  float64
#  9   company_location     78249 non-null   object
#  10  company_size         117677 non-null  object
#  11  years_of_experience  116018 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 13.1+ MB

# %%
data.dropna(inplace=True)

# %%
from sklearn.impute import SimpleImputer
imu=SimpleImputer(strategy='mean')
imu.fit(data[['work_year','remote_ratio','years_of_experience']])
data[['work_year','remote_ratio','years_of_experience']]=imu.transform(data[['work_year','remote_ratio','years_of_experience']])

# %%
imu=SimpleImputer(strategy='most_frequent')
imu.fit(data[['job_title','company_size','company_location']])
data[['job_title','company_size','company_location']]=imu.transform(data[['job_title','company_size','company_location']])

# %%
data.isna().sum()
# Out:
# work_year              0
# experience_level       0
# employment_type        0
# job_title              0
# salary                 0
# salary_currency        0
# salary_in_usd          0
# employee_residence     0
# remote_ratio           0
# company_location       0
# company_size           0
# years_of_experience    0
# dtype: int64

# %%
# imu1=SimpleImputer(strategy='most_frequent')
# result = imu1.fit_transform(data[['job_title']])
# data['job_title']=result.ravel

# %% [markdown]
# data.info()

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,Binarizer, OrdinalEncoder,LabelBinarizer

# %%
le =LabelEncoder()
data['experience_level']=le.fit_transform(data['experience_level'])
data['salary_currency']=le.fit_transform(data['salary_currency'])

# %%
ord=OrdinalEncoder(categories=[['S','M','L']])
data[['company_size']]=ord.fit_transform(data[['company_size']])

# %%
lb = LabelBinarizer()

lb_enc = lb.fit_transform(data['experience_level'])
lb_df = pd.DataFrame(
    lb_enc,
    columns=[f'lb_{c}' for c in lb.classes_],
    index=data.index 
)

# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

ohe = OneHotEncoder(sparse_output=False)

ohe_enc = ohe.fit_transform(data[['remote_ratio']])

ohe_df = pd.DataFrame(
    ohe_enc, 
       columns=ohe.get_feature_names_out(['remote_ratio']),

    index=data.index
)

data = pd.concat([data, ohe_df], axis=1)

# %%
data
copy=data

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.boxplot(data['salary'])
plt.subplot(1,2,2)
data.salary.plot(kind='hist')
plt.show()

# %%
def outliers_iqr(df, column_name="value"):
    Q1 = df[column_name].quantile(0.25)
    Q3 = df[column_name].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return df[(df[column_name] >= lower) & (df[column_name] <= upper)]

# %%
clean_data.shape
# Out:
# (42945, 15)

# %%
clean_data=outliers_iqr(data,'salary')

# %%
plt.boxplot(clean_data['salary'])

plt.show()
clean_data.salary.plot(kind='hist')
plt.show()

# %%
def capping(df,column):
    Q1=df[column].quantile(0.25)
    Q3=df[column].quantile(0.75)
    IQR = Q3 - Q1
    upper = Q3 + 1.5*IQR
    lower=Q1 - 1.5*IQR
    df[column]=np.clip(df[column],lower,upper)
    return df

# %%
copy.shape
# Out:
# (43911, 15)

# %%
clean_data_2=capping(copy,'salary')
plt.boxplot(clean_data_2['salary'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(clean_data_2.salary)
# Out:
# (array([1346., 4758., 7461., 8830., 7233., 5452., 3540., 2289., 1402.,
#         1600.]),
#  array([ 14400.,  47350.,  80300., 113250., 146200., 179150., 212100.,
#         245050., 278000., 310950., 343900.]),
#  <BarContainer object of 10 artists>)

# %%
clean_data_2.shape
# Out:
# (43911, 15)
